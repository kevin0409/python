# %%
n, m = map(int, input().split())
bucket = []
for r in range(n):
    bucket.append(r+1)

for _ in range(m):
    i, j = map(int, input().split())
    temp = bucket[i-1]
    bucket[i-1] = bucket[j-1]
    bucket[j-1] = temp
for k in range(0, n):
    print(bucket[k], end = ' ')
# Out:
# 5 4
# 1 2
# 3 4
# 1 4
# 2 2
# 3 1 4 2 5
