# %%
x, n = map(int, input().split())
x_list = []
x_list = list(map(int, input().split()))

for i in range(x):
    if x_list[i] < n:
        print(x_list[i], end = ' ')
# Out:
# 10 5
# 1 10 4 9 2 3 8 5 7 6
# 1 4 2 3
