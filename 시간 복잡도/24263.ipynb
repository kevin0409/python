# %%
import sys

n = sys.stdin.readline().rstrip('\n')
print(n)
print(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
# ----> 3 n = sys.stdin.readline().rstrip('\n')
#       4 print(n)
#       5 print(1)
#
# KeyboardInterrupt:
